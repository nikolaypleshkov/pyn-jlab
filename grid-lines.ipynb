# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 7, 100)

# %%
line1, = plt.plot(x, np.sin(x), label='sin')
line2, = plt.plot(x, np.cos(x), label='cos')

# %%
plt.legend(handles = [line1, line2], loc='lower right')

# %%
plt.grid(b = True, which = 'major', color='gray', alpha=0.6, linestyle = 'dashdot' , lw = 1.5)

plt.minortick_on()
plt.grid(b = True, which = 'minor', color='beige', alpha = 0.8, ls = '-', lw = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7235a6a86edd> in <module>
#       1 plt.grid(b = True, which = 'major', color='gray', alpha=0.6, linestyle = 'dashdot' , lw = 1.5)
#       2
# ----> 3 plt.minortick_on()
#       4 plt.grid(b = True, which = 'minor', color='beige', alpha = 0.8, ls = '-', lw = 1)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'minortick_on'

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 7, 100)
line1, = plt.plot(x, np.sin(x), label='sin')
line2, = plt.plot(x, np.cos(x), label='cos')
plt.legend(handles=[line1, line2], loc='lower right')
#major grid lines
plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
#minor grid lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='beige', alpha=0.8, ls='-', lw=1)
plt.show()
